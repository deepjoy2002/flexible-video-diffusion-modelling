# %% [markdown]
# <a href="https://colab.research.google.com/github/deepjoy2002/flexible-video-diffusion-modelling/blob/main/flexible-video-diffusion-modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/plai-group/flexible-video-diffusion-modeling.git
# Out:
# Cloning into 'flexible-video-diffusion-modeling'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 198 (delta 101), reused 142 (delta 60), pack-reused 0
# Receiving objects: 100% (198/198), 101.51 KiB | 3.50 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
# !python /content/flexible-video-diffusion-modeling/setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# !pip install lpips
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.5 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow==2.8 tensorflow_hub==0.12.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 45.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.15.0
#     Uninstalling tensorflow-hub-0.15.0:
# ...

# %%
# !python /content/flexible-video-diffusion-modeling/scripts/video_train.py
# Out:
# Traceback (most recent call last):
#   File "/content/flexible-video-diffusion-modeling/scripts/video_train.py", line 8, in <module>
#     import wandb
# ModuleNotFoundError: No module named 'wandb'

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 20.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=d4e9de38384294f8788d45cdb802c4ab2624162ed6b799b22c4ea8682806954b
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
import wandb

# Start a W&B Run with wandb.init
run = wandb.init(project="my_first_project")

# Save model inputs and hyperparameters in a wandb.config object
config = run.config
config.learning_rate = 0.01

# Model training code here ...

# Log metrics over time to visualize performance with wandb.log
export WANDB_ENTITY=<...>
export WANDB_PROJECT=<...>
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231027_061842-h9n8de7n</code>
# Syncing run <strong><a href='https://wandb.ai/aimlopsrandomtrees/my_first_project/runs/h9n8de7n' target="_blank">whole-frog-1</a></strong> to <a href='https://wandb.ai/aimlopsrandomtrees/my_first_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/aimlopsrandomtrees/my_first_project' target="_blank">https://wandb.ai/aimlopsrandomtrees/my_first_project</a>
# ...

# %%
# !export WANDB_ENTITY='entity/user-aimlopsrandomtrees'
# !export WANDB_PROJECT='my_first_project'

# %%
# !mkdir checkpoints

# %%
#!cd datasets/carla

# %%
#!bash download.sh

# %%
#!cd ../..

# %%
#!ls

# %%
#!cd datasets/carla

# %%
#!bash download.sh

# %%
# !bash /content/flexible-video-diffusion-modeling/datasets/carla/download.sh
# Out:
# --2023-10-27 06:36:05--  https://www.cs.ubc.ca/~wsgh/fdm/carla/no-traffic.tar.gz
# Resolving www.cs.ubc.ca (www.cs.ubc.ca)... 142.103.6.5
# Connecting to www.cs.ubc.ca (www.cs.ubc.ca)|142.103.6.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12982843046 (12G) [application/x-gzip]
# Saving to: ‘no-traffic.tar.gz’
#
# no-traffic.tar.gz   100%[===================>]  12.09G  24.0MB/s    in 8m 56s
#
# 2023-10-27 06:45:03 (23.1 MB/s) - ‘no-traffic.tar.gz’ saved [12982843046/12982843046]
#
# no-traffic/
# no-traffic/video_119.pt
# no-traffic/actions_123.npy
# no-traffic/coords_265.npy
# no-traffic/coords_70.npy
# no-traffic/coords_178.npy
# no-traffic/coords_141.npy
# no-traffic/video_190.pt
# no-traffic/actions_113.npy
# no-traffic/actions_325.npy
# no-traffic/coords_103.npy
# no-traffic/coords_186.npy
# no-traffic/coords_180.npy
# no-traffic/actions_212.npy
# no-traffic/video_440.pt
# no-traffic/actions_287.npy
# no-traffic/video_300.pt
# ...

# %%
# !python /content/flexible-video-diffusion-modeling/scripts/video_train.py --batch_size=2 --max_frames 20 --dataset=carla_no_traffic --num_res_blocks=1
# Out:
# Traceback (most recent call last):
#   File "/content/flexible-video-diffusion-modeling/scripts/video_train.py", line 11, in <module>
#     from improved_diffusion import dist_util
# ModuleNotFoundError: No module named 'improved_diffusion'

# %%
# !pip install improved_diffusion
